# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
    
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
               
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | bellary
# Processing Record 4 of Set 1 | zaltan
# Processing Record 5 of Set 1 | touros
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | pincher creek
# Processing Record 9 of Set 1 | victoria
# Processing Record 10 of Set 1 | aksu
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | khudumelapye
# Processing Record 15 of Set 1 | port lincoln
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | yulara
# Processing Record 18 of Set 1 | tsienyane
# City not found. Skipping...
# Processing Record 19 of Set 1 | sagar
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | manaure
# Processing Record 22 of Set 1 | nanortalik
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | yanchukan
# City not found. Skipping...
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | shubarkuduk
# Processing Record 28 of Set 1 | carpinteria
# Processing Record 29 of Set 1 | antalaha
# Processing Record 30 of Set 1 | grand-santi
# Processing Record 31 of Set 1 | zhanaozen
# Processing Record 32 of Set 1 | necochea
# Processing Record 33 of Set 1 | galle
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | katsuura
# Processing Record 36 of Set 1 | salalah
# Processing Record 37 of Set 1 | wuning
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | turka
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | bokoro
# Processing Record 42 of Set 1 | varnavino
# Processing Record 43 of Set 1 | ilulissat
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | dunedin
# Processing Record 46 of Set 1 | sukhoverkovo
# City not found. Skipping...
# Processing Record 47 of Set 1 | gangotri
# City not found. Skipping...
# Processing Record 48 of Set 1 | benavente
# Processing Record 49 of Set 1 | san patricio
# Processing Record 50 of Set 1 | moerai
# Processing Record 1 of Set 2 | steinbach
# Processing Record 2 of Set 2 | takoradi
# Processing Record 3 of Set 2 | arraial do cabo
# Processing Record 4 of Set 2 | makung
# City not found. Skipping...
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | taoudenni
# Processing Record 7 of Set 2 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 8 of Set 2 | chumikan
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | port-de-paix
# City not found. Skipping...
# Processing Record 11 of Set 2 | norman wells
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 15 of Set 2 | araguaina
# Processing Record 16 of Set 2 | iturama
# Processing Record 17 of Set 2 | cherskiy
# Processing Record 18 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | port hedland
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | ocos
# Processing Record 24 of Set 2 | mecca
# Processing Record 25 of Set 2 | biltine
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | tokur
# Processing Record 30 of Set 2 | chuy
# Processing Record 31 of Set 2 | klaksvik
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 34 of Set 2 | stornoway
# Processing Record 35 of Set 2 | bengkulu
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | negombo
# Processing Record 38 of Set 2 | aitape
# Processing Record 39 of Set 2 | ryotsu
# Processing Record 40 of Set 2 | camalu
# Processing Record 41 of Set 2 | nizhneudinsk
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | vaini
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | anori
# Processing Record 47 of Set 2 | ewo
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | jacksonville
# Processing Record 50 of Set 2 | muravlenko
# Processing Record 1 of Set 3 | the valley
# Processing Record 2 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 3 | hambantota
# Processing Record 4 of Set 3 | eura
# Processing Record 5 of Set 3 | arman
# Processing Record 6 of Set 3 | agadir
# Processing Record 7 of Set 3 | sao joao da barra
# Processing Record 8 of Set 3 | saldanha
# Processing Record 9 of Set 3 | alice
# Processing Record 10 of Set 3 | vestmannaeyjar
# Processing Record 11 of Set 3 | pandan
# Processing Record 12 of Set 3 | pisco
# Processing Record 13 of Set 3 | juegang
# Processing Record 14 of Set 3 | luderitz
# Processing Record 15 of Set 3 | tuatapere
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | portland
# Processing Record 18 of Set 3 | bluff
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | lorengau
# Processing Record 21 of Set 3 | dubai
# Processing Record 22 of Set 3 | pokhara
# Processing Record 23 of Set 3 | usak
# Processing Record 24 of Set 3 | sobolevo
# Processing Record 25 of Set 3 | jutai
# Processing Record 26 of Set 3 | port alfred
# Processing Record 27 of Set 3 | hof
# Processing Record 28 of Set 3 | ixtapa
# Processing Record 29 of Set 3 | jamestown
# Processing Record 30 of Set 3 | hualmay
# Processing Record 31 of Set 3 | victor harbor
# Processing Record 32 of Set 3 | liverpool
# Processing Record 33 of Set 3 | leninsk
# Processing Record 34 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 3 | srednekolymsk
# Processing Record 36 of Set 3 | bababe
# City not found. Skipping...
# Processing Record 37 of Set 3 | soe
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | barrow
# Processing Record 40 of Set 3 | saint-augustin
# Processing Record 41 of Set 3 | port elizabeth
# Processing Record 42 of Set 3 | san cristobal
# Processing Record 43 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | baykit
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 3 | mar del plata
# Processing Record 49 of Set 3 | souillac
# Processing Record 50 of Set 3 | hervey bay
# Processing Record 1 of Set 4 | zhigansk
# Processing Record 2 of Set 4 | gornyy
# Processing Record 3 of Set 4 | teguise
# Processing Record 4 of Set 4 | taos
# Processing Record 5 of Set 4 | emirdag
# Processing Record 6 of Set 4 | altamont
# Processing Record 7 of Set 4 | mgandu
# Processing Record 8 of Set 4 | caraquet
# Processing Record 9 of Set 4 | kidal
# Processing Record 10 of Set 4 | alta floresta
# Processing Record 11 of Set 4 | jalu
# Processing Record 12 of Set 4 | burnie
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | sorland
# Processing Record 15 of Set 4 | fare
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | kununurra
# Processing Record 18 of Set 4 | blythe
# Processing Record 19 of Set 4 | tiksi
# Processing Record 20 of Set 4 | vardo
# Processing Record 21 of Set 4 | oranjemund
# Processing Record 22 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 4 | mackay
# Processing Record 24 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 4 | saint austell
# Processing Record 26 of Set 4 | geraldton
# Processing Record 27 of Set 4 | rio claro
# Processing Record 28 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 4 | neuquen
# Processing Record 33 of Set 4 | airai
# Processing Record 34 of Set 4 | vao
# Processing Record 35 of Set 4 | haines junction
# Processing Record 36 of Set 4 | oktyabrskiy
# Processing Record 37 of Set 4 | isangel
# Processing Record 38 of Set 4 | longyearbyen
# Processing Record 39 of Set 4 | nakamura
# Processing Record 40 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 4 | fortuna
# Processing Record 42 of Set 4 | along
# Processing Record 43 of Set 4 | caravelas
# Processing Record 44 of Set 4 | qaanaaq
# Processing Record 45 of Set 4 | ginir
# Processing Record 46 of Set 4 | mandurah
# Processing Record 47 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 4 | yellowknife
# Processing Record 49 of Set 4 | bandarbeyla
# Processing Record 50 of Set 4 | anloga
# Processing Record 1 of Set 5 | hamilton
# Processing Record 2 of Set 5 | kaiyuan
# Processing Record 3 of Set 5 | gilgit
# Processing Record 4 of Set 5 | yamada
# Processing Record 5 of Set 5 | xining
# Processing Record 6 of Set 5 | makakilo city
# Processing Record 7 of Set 5 | grand forks
# Processing Record 8 of Set 5 | carroll
# Processing Record 9 of Set 5 | pampa
# Processing Record 10 of Set 5 | port-gentil
# Processing Record 11 of Set 5 | bredasdorp
# Processing Record 12 of Set 5 | charagua
# Processing Record 13 of Set 5 | santiago de cuba
# Processing Record 14 of Set 5 | whitehorse
# Processing Record 15 of Set 5 | okhotsk
# Processing Record 16 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 5 | shakawe
# Processing Record 18 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 19 of Set 5 | mount isa
# Processing Record 20 of Set 5 | saskylakh
# Processing Record 21 of Set 5 | preobrazheniye
# Processing Record 22 of Set 5 | miles city
# Processing Record 23 of Set 5 | mosquera
# Processing Record 24 of Set 5 | zavitinsk
# Processing Record 25 of Set 5 | santa rosalia
# Processing Record 26 of Set 5 | narsaq
# Processing Record 27 of Set 5 | kurilsk
# Processing Record 28 of Set 5 | verkhnevilyuysk
# Processing Record 29 of Set 5 | bilibino
# Processing Record 30 of Set 5 | jiuquan
# Processing Record 31 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 5 | almenara
# Processing Record 33 of Set 5 | pevek
# Processing Record 34 of Set 5 | spencer
# Processing Record 35 of Set 5 | mahebourg
# Processing Record 36 of Set 5 | monteagudo
# Processing Record 37 of Set 5 | cabo san lucas
# Processing Record 38 of Set 5 | nemuro
# Processing Record 39 of Set 5 | moose factory
# Processing Record 40 of Set 5 | lata
# Processing Record 41 of Set 5 | cagli
# Processing Record 42 of Set 5 | riachao das neves
# Processing Record 43 of Set 5 | vila franca do campo
# Processing Record 44 of Set 5 | urubicha
# Processing Record 45 of Set 5 | anjozorobe
# Processing Record 46 of Set 5 | nara
# Processing Record 47 of Set 5 | ashcroft
# Processing Record 48 of Set 5 | pecos
# Processing Record 49 of Set 5 | sakakah
# Processing Record 50 of Set 5 | provideniya
# Processing Record 1 of Set 6 | talnakh
# Processing Record 2 of Set 6 | san policarpo
# Processing Record 3 of Set 6 | santa cruz
# Processing Record 4 of Set 6 | inyonga
# Processing Record 5 of Set 6 | prince george
# Processing Record 6 of Set 6 | karratha
# Processing Record 7 of Set 6 | tomatlan
# Processing Record 8 of Set 6 | port hardy
# Processing Record 9 of Set 6 | natal
# Processing Record 10 of Set 6 | pio ix
# Processing Record 11 of Set 6 | clyde river
# Processing Record 12 of Set 6 | santa maria
# Processing Record 13 of Set 6 | kiama
# Processing Record 14 of Set 6 | port macquarie
# Processing Record 15 of Set 6 | coquimbo
# Processing Record 16 of Set 6 | half moon bay
# Processing Record 17 of Set 6 | kathmandu
# Processing Record 18 of Set 6 | tiznit
# Processing Record 19 of Set 6 | novo aripuana
# Processing Record 20 of Set 6 | tommot
# Processing Record 21 of Set 6 | bethel
# Processing Record 22 of Set 6 | talcahuano
# Processing Record 23 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 24 of Set 6 | aden
# Processing Record 25 of Set 6 | riyadh
# Processing Record 26 of Set 6 | tura
# Processing Record 27 of Set 6 | labytnangi
# Processing Record 28 of Set 6 | east london
# Processing Record 29 of Set 6 | cairns
# Processing Record 30 of Set 6 | verkhnyaya inta
# Processing Record 31 of Set 6 | dillon
# Processing Record 32 of Set 6 | belaya gora
# Processing Record 33 of Set 6 | nieuw amsterdam
# Processing Record 34 of Set 6 | alice springs
# Processing Record 35 of Set 6 | farah
# Processing Record 36 of Set 6 | korla
# Processing Record 37 of Set 6 | eureka
# Processing Record 38 of Set 6 | khani
# Processing Record 39 of Set 6 | kahului
# Processing Record 40 of Set 6 | faanui
# Processing Record 41 of Set 6 | puerto ayora
# Processing Record 42 of Set 6 | kaspiyskiy
# Processing Record 43 of Set 6 | marawi
# Processing Record 44 of Set 6 | aldan
# Processing Record 45 of Set 6 | kavieng
# Processing Record 46 of Set 6 | beatrice
# Processing Record 47 of Set 6 | bambous virieux
# Processing Record 48 of Set 6 | berdigestyakh
# Processing Record 49 of Set 6 | grand gaube
# Processing Record 50 of Set 6 | port shepstone
# Processing Record 1 of Set 7 | nha trang
# Processing Record 2 of Set 7 | basoko
# Processing Record 3 of Set 7 | upata
# Processing Record 4 of Set 7 | okha
# Processing Record 5 of Set 7 | lock haven
# Processing Record 6 of Set 7 | leningradskiy
# Processing Record 7 of Set 7 | juneau
# Processing Record 8 of Set 7 | kaitangata
# Processing Record 9 of Set 7 | alexandria
# Processing Record 10 of Set 7 | nuuk
# Processing Record 11 of Set 7 | ardahan
# Processing Record 12 of Set 7 | amapa
# Processing Record 13 of Set 7 | sadovoye
# Processing Record 14 of Set 7 | jacqueville
# Processing Record 15 of Set 7 | atlantic city
# Processing Record 16 of Set 7 | gamba
# Processing Record 17 of Set 7 | kavaratti
# Processing Record 18 of Set 7 | trinidad
# Processing Record 19 of Set 7 | roebourne
# Processing Record 20 of Set 7 | palmer
# Processing Record 21 of Set 7 | huilong
# Processing Record 22 of Set 7 | ambon
# Processing Record 23 of Set 7 | mitchell
# Processing Record 24 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 7 | kieta
# Processing Record 26 of Set 7 | suzu
# City not found. Skipping...
# Processing Record 27 of Set 7 | husavik
# Processing Record 28 of Set 7 | sokoto
# Processing Record 29 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 30 of Set 7 | villazon
# Processing Record 31 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 32 of Set 7 | yar-sale
# Processing Record 33 of Set 7 | grindavik
# Processing Record 34 of Set 7 | kielce
# Processing Record 35 of Set 7 | slonim
# Processing Record 36 of Set 7 | shimoga
# Processing Record 37 of Set 7 | seoul
# Processing Record 38 of Set 7 | guiratinga
# Processing Record 39 of Set 7 | sao filipe
# Processing Record 40 of Set 7 | aljezur
# Processing Record 41 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 7 | carnarvon
# Processing Record 43 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 7 | jackson
# Processing Record 45 of Set 7 | shimoda
# Processing Record 46 of Set 7 | boa vista
# Processing Record 47 of Set 7 | hobyo
# Processing Record 48 of Set 7 | iracoubo
# Processing Record 49 of Set 7 | costinesti
# Processing Record 50 of Set 7 | alofi
# Processing Record 1 of Set 8 | constitucion
# Processing Record 2 of Set 8 | bongaree
# Processing Record 3 of Set 8 | asfi
# Processing Record 4 of Set 8 | waddan
# Processing Record 5 of Set 8 | poum
# Processing Record 6 of Set 8 | avera
# Processing Record 7 of Set 8 | shaoxing
# Processing Record 8 of Set 8 | salamanca
# Processing Record 9 of Set 8 | laguna
# Processing Record 10 of Set 8 | bermeo
# Processing Record 11 of Set 8 | trofors
# Processing Record 12 of Set 8 | great yarmouth
# Processing Record 13 of Set 8 | ballina
# Processing Record 14 of Set 8 | bahia honda
# Processing Record 15 of Set 8 | biskamzha
# Processing Record 16 of Set 8 | morgan city
# Processing Record 17 of Set 8 | atambua
# Processing Record 18 of Set 8 | sevlievo
# Processing Record 19 of Set 8 | iqaluit
# Processing Record 20 of Set 8 | olafsvik
# Processing Record 21 of Set 8 | fairbanks
# Processing Record 22 of Set 8 | labuhan
# Processing Record 23 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 8 | ust-tsilma
# Processing Record 25 of Set 8 | najran
# Processing Record 26 of Set 8 | buraydah
# Processing Record 27 of Set 8 | pozo colorado
# Processing Record 28 of Set 8 | almaznyy
# Processing Record 29 of Set 8 | zhangjiakou
# Processing Record 30 of Set 8 | ambovombe
# Processing Record 31 of Set 8 | cayenne
# Processing Record 32 of Set 8 | santiago de cao
# Processing Record 33 of Set 8 | cochrane
# Processing Record 34 of Set 8 | lovington
# Processing Record 35 of Set 8 | hinton
# Processing Record 36 of Set 8 | kupang
# Processing Record 37 of Set 8 | huarmey
# Processing Record 38 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 8 | dumas
# Processing Record 40 of Set 8 | senanga
# Processing Record 41 of Set 8 | roseburg
# Processing Record 42 of Set 8 | brand-erbisdorf
# Processing Record 43 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 44 of Set 8 | cavaillon
# Processing Record 45 of Set 8 | ulaanbaatar
# Processing Record 46 of Set 8 | nouadhibou
# Processing Record 47 of Set 8 | abonnema
# Processing Record 48 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 8 | traralgon
# Processing Record 50 of Set 8 | arona
# Processing Record 1 of Set 9 | galesong
# Processing Record 2 of Set 9 | torbay
# Processing Record 3 of Set 9 | marquette
# Processing Record 4 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 9 | egvekinot
# Processing Record 6 of Set 9 | vanavara
# Processing Record 7 of Set 9 | mocuba
# Processing Record 8 of Set 9 | iranshahr
# Processing Record 9 of Set 9 | berthierville
# Processing Record 10 of Set 9 | mundwa
# Processing Record 11 of Set 9 | charters towers
# Processing Record 12 of Set 9 | roshal
# Processing Record 13 of Set 9 | malaryta
# Processing Record 14 of Set 9 | inirida
# Processing Record 15 of Set 9 | severo-kurilsk
# Processing Record 16 of Set 9 | kungurtug
# Processing Record 17 of Set 9 | jiexiu
# Processing Record 18 of Set 9 | salinopolis
# Processing Record 19 of Set 9 | kinablangan
# Processing Record 20 of Set 9 | sembakung
# Processing Record 21 of Set 9 | muncie
# Processing Record 22 of Set 9 | storforshei
# Processing Record 23 of Set 9 | hami
# Processing Record 24 of Set 9 | ancud
# Processing Record 25 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 26 of Set 9 | gondanglegi
# Processing Record 27 of Set 9 | soroti
# Processing Record 28 of Set 9 | bafq
# Processing Record 29 of Set 9 | paamiut
# Processing Record 30 of Set 9 | la ronge
# Processing Record 31 of Set 9 | kaeo
# Processing Record 32 of Set 9 | bilma
# Processing Record 33 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 9 | katiola
# Processing Record 35 of Set 9 | puerto santander
# Processing Record 36 of Set 9 | skovorodino
# Processing Record 37 of Set 9 | ust-tarka
# Processing Record 38 of Set 9 | north platte
# Processing Record 39 of Set 9 | smirnykh
# Processing Record 40 of Set 9 | mogadishu
# Processing Record 41 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 42 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 9 | saint anthony
# Processing Record 44 of Set 9 | muros
# Processing Record 45 of Set 9 | floro
# Processing Record 46 of Set 9 | norwich
# Processing Record 47 of Set 9 | kruisfontein
# Processing Record 48 of Set 9 | hit
# Processing Record 49 of Set 9 | boden
# Processing Record 50 of Set 9 | sorong
# Processing Record 1 of Set 10 | henties bay
# Processing Record 2 of Set 10 | udachnyy
# Processing Record 3 of Set 10 | feltre
# Processing Record 4 of Set 10 | kadom
# Processing Record 5 of Set 10 | te anau
# Processing Record 6 of Set 10 | pangnirtung
# Processing Record 7 of Set 10 | naze
# Processing Record 8 of Set 10 | bratsk
# Processing Record 9 of Set 10 | tiarei
# Processing Record 10 of Set 10 | zyryanovsk
# Processing Record 11 of Set 10 | aripuana
# Processing Record 12 of Set 10 | buchanan
# Processing Record 13 of Set 10 | christchurch
# Processing Record 14 of Set 10 | guerrero negro
# Processing Record 15 of Set 10 | solnechnyy
# Processing Record 16 of Set 10 | codrington
# Processing Record 17 of Set 10 | pacific grove
# Processing Record 18 of Set 10 | barranca
# Processing Record 19 of Set 10 | fort nelson
# Processing Record 20 of Set 10 | ritchie
# Processing Record 21 of Set 10 | sile
# Processing Record 22 of Set 10 | ibotirama
# Processing Record 23 of Set 10 | canyon
# Processing Record 24 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 25 of Set 10 | kalengwa
# Processing Record 26 of Set 10 | nuevo progreso
# Processing Record 27 of Set 10 | namibe
# Processing Record 28 of Set 10 | am timan
# Processing Record 29 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 10 | svetlogorsk
# Processing Record 31 of Set 10 | oyama
# Processing Record 32 of Set 10 | lavrentiya
# Processing Record 33 of Set 10 | hofn
# Processing Record 34 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 10 | celestun
# Processing Record 36 of Set 10 | rancho palos verdes
# Processing Record 37 of Set 10 | mercedes
# Processing Record 38 of Set 10 | chipinge
# Processing Record 39 of Set 10 | ileza
# Processing Record 40 of Set 10 | kasempa
# Processing Record 41 of Set 10 | sayyan
# Processing Record 42 of Set 10 | grand haven
# Processing Record 43 of Set 10 | porto belo
# Processing Record 44 of Set 10 | george
# Processing Record 45 of Set 10 | conde
# Processing Record 46 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 47 of Set 10 | gloversville
# Processing Record 48 of Set 10 | zhangye
# Processing Record 49 of Set 10 | kamenka
# Processing Record 50 of Set 10 | ushtobe
# Processing Record 1 of Set 11 | vostok
# Processing Record 2 of Set 11 | manjeshwar
# Processing Record 3 of Set 11 | sur
# Processing Record 4 of Set 11 | skibbereen
# Processing Record 5 of Set 11 | kalyazin
# Processing Record 6 of Set 11 | san buenaventura
# Processing Record 7 of Set 11 | brigantine
# Processing Record 8 of Set 11 | griffith
# Processing Record 9 of Set 11 | saint-ambroise
# Processing Record 10 of Set 11 | buin
# Processing Record 11 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 12 of Set 11 | hasaki
# Processing Record 13 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 14 of Set 11 | henzada
# City not found. Skipping...
# Processing Record 15 of Set 11 | vitimskiy
# City not found. Skipping...
# Processing Record 16 of Set 11 | ketchikan
# Processing Record 17 of Set 11 | gazli
# Processing Record 18 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 11 | prainha
# Processing Record 20 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 11 | lima
# Processing Record 22 of Set 11 | allapalli
# Processing Record 23 of Set 11 | plaster rock
# Processing Record 24 of Set 11 | brae
# Processing Record 25 of Set 11 | prince rupert
# Processing Record 26 of Set 11 | zaraza
# Processing Record 27 of Set 11 | butterworth
# Processing Record 28 of Set 11 | afyonkarahisar
# Processing Record 29 of Set 11 | olenegorsk
# Processing Record 30 of Set 11 | westport
# Processing Record 31 of Set 11 | ouahigouya
# Processing Record 32 of Set 11 | mugreyevskiy
# City not found. Skipping...
# Processing Record 33 of Set 11 | coihaique
# Processing Record 34 of Set 11 | sabha
# Processing Record 35 of Set 11 | itsukaichi
# Processing Record 36 of Set 11 | carmelo
# Processing Record 37 of Set 11 | daru
# Processing Record 38 of Set 11 | yemtsa
# Processing Record 39 of Set 11 | yangliuqing
# Processing Record 40 of Set 11 | olinda
# Processing Record 41 of Set 11 | aklavik
# Processing Record 42 of Set 11 | chala
# Processing Record 43 of Set 11 | bonthe
# Processing Record 44 of Set 11 | ostrovnoy
# Processing Record 45 of Set 11 | santa barbara
# Processing Record 46 of Set 11 | umm lajj
# Processing Record 47 of Set 11 | asau
# Processing Record 48 of Set 11 | maturin
# Processing Record 49 of Set 11 | maceio
# Processing Record 50 of Set 11 | bayonet point
# Processing Record 1 of Set 12 | eldoret
# Processing Record 2 of Set 12 | daye
# Processing Record 3 of Set 12 | impfondo
# Processing Record 4 of Set 12 | merrill
# Processing Record 5 of Set 12 | tecoanapa
# Processing Record 6 of Set 12 | norfolk
# Processing Record 7 of Set 12 | kapoeta
# Processing Record 8 of Set 12 | matara
# Processing Record 9 of Set 12 | dakar
# Processing Record 10 of Set 12 | lucapa
# Processing Record 11 of Set 12 | paita
# Processing Record 12 of Set 12 | flin flon
# Processing Record 13 of Set 12 | irshava
# Processing Record 14 of Set 12 | scottsbluff
# Processing Record 15 of Set 12 | itarema
# Processing Record 16 of Set 12 | dudinka
# Processing Record 17 of Set 12 | tarata
# Processing Record 18 of Set 12 | mongo
# Processing Record 19 of Set 12 | galesburg
# Processing Record 20 of Set 12 | sitka
# Processing Record 21 of Set 12 | rio gallegos
# Processing Record 22 of Set 12 | rawson
# Processing Record 23 of Set 12 | namatanai
# Processing Record 24 of Set 12 | san pedro de macoris
# Processing Record 25 of Set 12 | seydi
# Processing Record 26 of Set 12 | pasni
# Processing Record 27 of Set 12 | izhma
# Processing Record 28 of Set 12 | coruripe
# Processing Record 29 of Set 12 | berberati
# Processing Record 30 of Set 12 | gravdal
# Processing Record 31 of Set 12 | turukhansk
# Processing Record 32 of Set 12 | bud
# Processing Record 33 of Set 12 | los llanos de aridane
# Processing Record 34 of Set 12 | mount gambier
# Processing Record 35 of Set 12 | bathsheba
# Processing Record 36 of Set 12 | mingaora
# Processing Record 37 of Set 12 | zhezkazgan
# Processing Record 38 of Set 12 | benalla
# Processing Record 39 of Set 12 | villa del rosario
# Processing Record 40 of Set 12 | luwuk
# Processing Record 41 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 42 of Set 12 | severo-yeniseyskiy
# Processing Record 43 of Set 12 | noumea
# Processing Record 44 of Set 12 | pangoa
# Processing Record 45 of Set 12 | rundu
# Processing Record 46 of Set 12 | porto nacional
# Processing Record 47 of Set 12 | ampanihy
# Processing Record 48 of Set 12 | vaitape
# Processing Record 49 of Set 12 | beringovskiy
# Processing Record 50 of Set 12 | nenita
# Processing Record 1 of Set 13 | hukeri
# Processing Record 2 of Set 13 | evensk
# Processing Record 3 of Set 13 | grootfontein
# Processing Record 4 of Set 13 | borovoy
# Processing Record 5 of Set 13 | manta
# Processing Record 6 of Set 13 | mayo
# Processing Record 7 of Set 13 | inhambane
# Processing Record 8 of Set 13 | kokopo
# Processing Record 9 of Set 13 | derzhavinsk
# Processing Record 10 of Set 13 | san quintin
# Processing Record 11 of Set 13 | faya
# Processing Record 12 of Set 13 | west lafayette
# Processing Record 13 of Set 13 | merauke
# Processing Record 14 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 13 | leh
# Processing Record 17 of Set 13 | anadyr
# Processing Record 18 of Set 13 | tambura
# Processing Record 19 of Set 13 | carahue
# Processing Record 20 of Set 13 | plettenberg bay
# Processing Record 21 of Set 13 | mrakovo
# Processing Record 22 of Set 13 | ardakan
# Processing Record 23 of Set 13 | lompoc
# Processing Record 24 of Set 13 | mae sot
# Processing Record 25 of Set 13 | igarka
# Processing Record 26 of Set 13 | slave lake
# Processing Record 27 of Set 13 | lazaro cardenas
# Processing Record 28 of Set 13 | tshela
# Processing Record 29 of Set 13 | kribi
# Processing Record 30 of Set 13 | maymyo
# Processing Record 31 of Set 13 | rio grande
# Processing Record 32 of Set 13 | deputatskiy
# Processing Record 33 of Set 13 | wajir
# Processing Record 34 of Set 13 | sosua
# Processing Record 35 of Set 13 | sambava
# Processing Record 36 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 13 | puta
# Processing Record 38 of Set 13 | kyra
# Processing Record 39 of Set 13 | ormara
# Processing Record 40 of Set 13 | vianopolis
# Processing Record 41 of Set 13 | mangrol
# Processing Record 42 of Set 13 | wembley
# Processing Record 43 of Set 13 | vila velha
# Processing Record 44 of Set 13 | moree
# Processing Record 45 of Set 13 | isabela
# Processing Record 46 of Set 13 | sao paulo de olivenca
# Processing Record 47 of Set 13 | ola
# Processing Record 48 of Set 13 | northam
# Processing Record 49 of Set 13 | altamira
# Processing Record 50 of Set 13 | atherton
# Processing Record 1 of Set 14 | safaga
# Processing Record 2 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 3 of Set 14 | kutum
# Processing Record 4 of Set 14 | cap malheureux
# Processing Record 5 of Set 14 | sibolga
# Processing Record 6 of Set 14 | ous
# Processing Record 7 of Set 14 | le vauclin
# Processing Record 8 of Set 14 | iisalmi
# Processing Record 9 of Set 14 | whyalla
# Processing Record 10 of Set 14 | khakhea
# Processing Record 11 of Set 14 | wukari
# Processing Record 12 of Set 14 | zeya
# Processing Record 13 of Set 14 | gazojak
# Processing Record 14 of Set 14 | grand-lahou
# Processing Record 15 of Set 14 | chapais
# Processing Record 16 of Set 14 | tawnat
# City not found. Skipping...
# Processing Record 17 of Set 14 | dingle
# Processing Record 18 of Set 14 | cururupu
# Processing Record 19 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 20 of Set 14 | surt
# Processing Record 21 of Set 14 | awjilah
# Processing Record 22 of Set 14 | forio
# Processing Record 23 of Set 14 | mahanoro
# Processing Record 24 of Set 14 | west odessa
# Processing Record 25 of Set 14 | lasa
# Processing Record 26 of Set 14 | lar
# Processing Record 27 of Set 14 | bathurst
# Processing Record 28 of Set 14 | novaya igirma
# Processing Record 29 of Set 14 | barra
# Processing Record 30 of Set 14 | bowen
# Processing Record 31 of Set 14 | monrovia
# Processing Record 32 of Set 14 | omboue
# Processing Record 33 of Set 14 | praia
# Processing Record 34 of Set 14 | birao
# Processing Record 35 of Set 14 | greenwood
# Processing Record 36 of Set 14 | gushikawa
# Processing Record 37 of Set 14 | krasnoselkup
# Processing Record 38 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 14 | neryungri
# Processing Record 40 of Set 14 | milkovo
# Processing Record 41 of Set 14 | yaring
# Processing Record 42 of Set 14 | palatka
# Processing Record 43 of Set 14 | metehara
# City not found. Skipping...
# Processing Record 44 of Set 14 | huron
# Processing Record 45 of Set 14 | doha
# Processing Record 46 of Set 14 | bereda
# Processing Record 47 of Set 14 | jingdezhen
# Processing Record 48 of Set 14 | van buren
# Processing Record 49 of Set 14 | stony plain
# Processing Record 50 of Set 14 | tocopilla
# Processing Record 1 of Set 15 | karamay
# City not found. Skipping...
# Processing Record 2 of Set 15 | tynda
# Processing Record 3 of Set 15 | baruun-urt
# Processing Record 4 of Set 15 | labrea
# Processing Record 5 of Set 15 | shepsi
# Processing Record 6 of Set 15 | hamina
# Processing Record 7 of Set 15 | morehead
# Processing Record 8 of Set 15 | shahreza
# Processing Record 9 of Set 15 | lovozero
# Processing Record 10 of Set 15 | kjollefjord
# Processing Record 11 of Set 15 | songea
# Processing Record 12 of Set 15 | mataram
# Processing Record 13 of Set 15 | kangaatsiaq
# Processing Record 14 of Set 15 | havelian
# Processing Record 15 of Set 15 | lucea
# Processing Record 16 of Set 15 | oksfjord
# Processing Record 17 of Set 15 | richards bay
# Processing Record 18 of Set 15 | port blair
# Processing Record 19 of Set 15 | kamakwie
# Processing Record 20 of Set 15 | nadvoitsy
# Processing Record 21 of Set 15 | ereymentau
# Processing Record 22 of Set 15 | nchelenge
# Processing Record 23 of Set 15 | north bend
# Processing Record 24 of Set 15 | tautira
# Processing Record 25 of Set 15 | baft
# Processing Record 26 of Set 15 | sao gabriel da cachoeira
# Processing Record 27 of Set 15 | bardiyah
# Processing Record 28 of Set 15 | flinders
# Processing Record 29 of Set 15 | key largo
# Processing Record 30 of Set 15 | kysyl-syr
# Processing Record 31 of Set 15 | kiunga
# Processing Record 32 of Set 15 | west bay
# Processing Record 33 of Set 15 | kwinana
# Processing Record 34 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 35 of Set 15 | wattegama
# Processing Record 36 of Set 15 | mions
# Processing Record 37 of Set 15 | lagoa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Cape Town -33.9258  18.4232     57.09        82          75        3.44
# 1    Bellary  15.1500  76.9333     83.88        59           8        6.93
# 2     Zaltan  32.9470  11.8665     68.29        75           1        1.68
# 3     Touros  -5.1989 -35.4608     76.10        83           7       12.66
# 4   Cidreira -30.1811 -50.2056     60.21        91          29        7.63
#
#   Country Current Description
# 0      ZA       moderate rain
# 1      IN           clear sky
# 2      LY           clear sky
# 3      BR           clear sky
# 4      BR    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Cape Town      ZA -33.9258   18.4232     57.09        82          75
# 1      Bellary      IN  15.1500   76.9333     83.88        59           8
# 2       Zaltan      LY  32.9470   11.8665     68.29        75           1
# 3       Touros      BR  -5.1989  -35.4608     76.10        83           7
# 4     Cidreira      BR -30.1811  -50.2056     60.21        91          29
# ..         ...     ...      ...       ...       ...       ...         ...
# 664   West Bay      KY  19.3667  -81.4167     82.99        82           1
# 665    Kwinana      AU -32.2500  115.7667     66.81        62          84
# 666  Wattegama      LK   6.7989   81.4808     79.72        59          67
# 667      Mions      FR  45.6643    4.9499     60.94        85           0
# 668      Lagoa      PT  39.0500  -27.9833     70.41        91           8
#
#      Wind Speed Current Description
# 0          3.44       moderate rain
# 1          6.93           clear sky
# 2          1.68           clear sky
# 3         12.66           clear sky
# 4          7.63    scattered clouds
# ..          ...                 ...
# 664        1.99           clear sky
# 665        5.99       broken clouds
# 666        3.53       broken clouds
# 667        4.61           clear sky
# 668       15.43           clear sky
#
# [669 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
